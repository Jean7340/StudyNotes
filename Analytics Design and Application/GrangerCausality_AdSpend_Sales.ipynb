# %%
from statsmodels.tsa.stattools import grangercausalitytests
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("AdSpend_Sales.csv")
data = data.set_index('Week')
data
# Out:
#          Ad_Spend        Sales
# Week
# 1      549.671415     0.000000
# 2      495.882308   434.393501
# 3      584.186330   809.897775
# 4      681.429199   728.774972
# 5      515.419614   898.003701
# ...           ...          ...
# 100   1437.706335     9.431698
# 101   1329.336712   -19.039745
# 102   1438.517992   929.354819
# 103   1456.019810  1359.375140
# 104   1419.772273  1071.549262
#
# [104 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.index, data["Ad_Spend"], label="Ad Spend", alpha=0.8)
plt.plot(data.index, data["Sales"], label="Sales", alpha=0.8)
plt.title("Time Series: Ad Spend vs. Sales")
plt.xlabel("Week")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
# Perform Granger Causality test
test_result = grangercausalitytests(data[["Sales", "Ad_Spend"]], maxlag = 5)

wald_stat = test_result[1][0]['ssr_ftest'][0]
p_value = test_result[1][0]['ssr_ftest'][1]
print(f"Lag {1}: Wald statistic = {wald_stat}, p-value = {p_value}")
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.6312  , p=0.0196  , df_denom=100, df_num=1
# ssr based chi2 test:   chi2=5.8001  , p=0.0160  , df=1
# likelihood ratio test: chi2=5.6427  , p=0.0175  , df=1
# parameter F test:         F=5.6312  , p=0.0196  , df_denom=100, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.3901  , p=0.0377  , df_denom=97, df_num=2
# ssr based chi2 test:   chi2=7.1297  , p=0.0283  , df=2
# likelihood ratio test: chi2=6.8916  , p=0.0319  , df=2
# parameter F test:         F=3.3901  , p=0.0377  , df_denom=97, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.3273  , p=0.0229  , df_denom=94, df_num=3
# ssr based chi2 test:   chi2=10.7253 , p=0.0133  , df=3
# likelihood ratio test: chi2=10.1932 , p=0.0170  , df=3
# parameter F test:         F=3.3273  , p=0.0229  , df_denom=94, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...
